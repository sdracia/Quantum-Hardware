# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("File1/File1_nozoom.csv", skiprows = range(0, 11))

# %%
fig = plt.figure(figsize=(15, 8))
plt.plot(data)
